# %%
import pandas as pd

melb_data = pd.read_csv('data/melb_data.csv', sep=',')
display(melb_data)
# Out:
#        index         Suburb           Address  Rooms Type      Price Method  \
# 0          0     Abbotsford      85 Turner St      2    h  1480000.0      S
# 1          1     Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2          2     Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3          3     Abbotsford  40 Federation La      3    h   850000.0     PI
# 4          4     Abbotsford       55a Park St      4    h  1600000.0     VB
# ...      ...            ...               ...    ...  ...        ...    ...
# 13575  13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576  13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577  13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578  13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579  13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
# ...

# %%
print(melb_data.loc[15]['Price'])
print(melb_data.loc[90]['Date'])
print(round(melb_data.loc[3521]['Landsize']/melb_data.loc[1690]['Landsize'], 0))
# Out:
# 1310000.0
# 10/09/2016
# 3.0

# %%
display(melb_data.head())
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...  1.0     202.0         126.0     1970.0
# 1  4/02/2016       2.5  ...  0.0     156.0          79.0     1900.0
# 2  4/03/2017       2.5  ...  0.0     134.0         150.0     1900.0
# 3  4/03/2017       2.5  ...  1.0      94.0         126.0     1970.0
# 4  4/06/2016       2.5  ...  2.0     120.0         142.0     2014.0
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# ...

# %%
melb_data.tail(7)
# Out:
#        index         Suburb        Address  Rooms Type      Price Method  \
# 13573  13573       Werribee    5 Nuragi Ct      4    h   635000.0      S
# 13574  13574    Westmeadows     9 Black St      3    h   582000.0      S
# 13575  13575  Wheelers Hill   12 Strada Cr      4    h  1245000.0      S
# 13576  13576   Williamstown  77 Merrett Dr      3    h  1031000.0     SP
# 13577  13577   Williamstown    83 Power St      3    h  1170000.0      S
# 13578  13578   Williamstown   96 Verdon St      4    h  2500000.0     PI
# 13579  13579     Yarraville     6 Agnes St      4    h  1285000.0     SP
#
#              SellerG        Date  Distance  ...  Car  Landsize  BuildingArea  \
# 13573  hockingstuart  26/08/2017      14.7  ...  1.0     662.0         172.0
# 13574            Red  26/08/2017      16.5  ...  2.0     256.0         126.0
# 13575          Barry  26/08/2017      16.7  ...  2.0     652.0         126.0
# ...

# %%
 melb_data.shape
# Out:
# (13580, 23)

# %%
melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  float64
#  12  Bathroom       13580 non-null  float64
#  13  Car            13580 non-null  float64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  float64
# ...

# %%
melb_data['Car'] = melb_data['Car'].astype('int64')
melb_data['Bedroom'] = melb_data['Bedroom'].astype('int64')
melb_data['Bathroom'] = melb_data['Bathroom'].astype('int64')
melb_data['Propertycount'] = melb_data['Propertycount'].astype('int64')
melb_data['YearBuilt'] = melb_data['YearBuilt'].astype('int64')
melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  int64
#  12  Bathroom       13580 non-null  int64
#  13  Car            13580 non-null  int64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  int64
# ...

# %%
melb_data.dtypes
# Out:
# index              int64
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode           int64
# Bedroom            int64
# Bathroom           int64
# Car                int64
# Landsize         float64
# BuildingArea     float64
# YearBuilt          int64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount      int64
# Coordinates       object
# dtype: object

# %%
melb_data.describe().loc[:, ['Distance', 'BuildingArea' , 'Price']]
# Out:
#            Distance  BuildingArea         Price
# count  13580.000000  13580.000000  1.358000e+04
# mean      10.137776    139.633972  1.075684e+06
# std        5.868725    392.217403  6.393107e+05
# min        0.000000      0.000000  8.500000e+04
# 25%        6.100000    122.000000  6.500000e+05
# 50%        9.200000    126.000000  9.030000e+05
# 75%       13.000000    129.940000  1.330000e+06
# max       48.100000  44515.000000  9.000000e+06

# %%
melb_data.loc[:, ['Distance', 'BuildingArea' , 'Price']].describe()
# Out:
#            Distance  BuildingArea         Price
# count  13580.000000  13580.000000  1.358000e+04
# mean      10.137776    139.633972  1.075684e+06
# std        5.868725    392.217403  6.393107e+05
# min        0.000000      0.000000  8.500000e+04
# 25%        6.100000    122.000000  6.500000e+05
# 50%        9.200000    126.000000  9.030000e+05
# 75%       13.000000    129.940000  1.330000e+06
# max       48.100000  44515.000000  9.000000e+06

# %%
melb_data.describe(include=['object'])
# Out:
#            Suburb       Address   Type Method SellerG        Date CouncilArea  \
# count       13580         13580  13580  13580   13580       13580       12211
# unique        314         13378      3      5     268          58          33
# top     Reservoir  5 Charles St      h      S  Nelson  27/05/2017    Moreland
# freq          359             3   9449   9022    1565         473        1163
#
#                    Regionname         Coordinates
# count                   13580               13580
# unique                      8               13097
# top     Southern Metropolitan  -37.8361, 144.9966
# freq                     4695                  12

# %%
melb_data['Regionname'].value_counts()
# Out:
# Regionname
# Southern Metropolitan         4695
# Northern Metropolitan         3890
# Western Metropolitan          2948
# Eastern Metropolitan          1471
# South-Eastern Metropolitan     450
# Eastern Victoria                53
# Northern Victoria               41
# Western Victoria                32
# Name: count, dtype: int64

# %%
melb_data['Regionname'].value_counts(normalize=True)
# Out:
# Regionname
# Southern Metropolitan         0.345729
# Northern Metropolitan         0.286451
# Western Metropolitan          0.217084
# Eastern Metropolitan          0.108321
# South-Eastern Metropolitan    0.033137
# Eastern Victoria              0.003903
# Northern Victoria             0.003019
# Western Victoria              0.002356
# Name: proportion, dtype: float64

# %%
melb_data['Type'].value_counts(normalize=True)
# Out:
# Type
# h    0.695803
# u    0.222165
# t    0.082032
# Name: proportion, dtype: float64

# %%
print(melb_data['Price'].mean())
# Out:
# 1075684.079455081

# %%
rate = 0.12
income = melb_data['Price'].sum() * rate
print('Total income of real estate agencies:', round(income, 2))
# Out:
# Total income of real estate agencies: 1752934775.88

# %%
landsize_median = melb_data['Landsize'].median() 
landsize_mean =  melb_data['Landsize'].mean()
print(abs(landsize_median - landsize_mean)/landsize_mean)
# difference between mean and median landsize
# Out:
# 0.21205713983546193

# %%
print(melb_data['Rooms'].mode())
# Out:
# 0    3
# Name: Rooms, dtype: int64

# %%
melb_data['Regionname'].mode()
# Out:
# 0    Southern Metropolitan
# Name: Regionname, dtype: object

# %%
len(melb_data[melb_data['Regionname']=='Southern Metropolitan'])
# Out:
# 4695

# %%
abs(melb_data['BuildingArea'].median()/melb_data['BuildingArea'].mean()-1)*100
# Out:
# np.float64(9.764079662364534)

# %%
mask = melb_data['Price'] > 2000000
display(mask)
display(melb_data[mask].head())
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13575    False
# 13576    False
# 13577    False
# 13578     True
# 13579    False
# Name: Price, Length: 13580, dtype: bool
#     index       Suburb               Address  Rooms Type      Price Method  \
# 80     80  Albert Park  112 Beaconsfield Pde      3    h  2850000.0     PI
# 85     85  Albert Park     104 Richardson St      4    h  2300000.0      S
# 88     88  Albert Park        29 Faussett St      2    h  2120000.0      S
# 92     92  Albert Park           2 Dundas Pl      3    h  2615000.0      S
# 93     93  Albert Park          23 Finlay St      5    h  2100000.0      S
#
#      SellerG        Date  Distance  ...  Car  Landsize  BuildingArea  \
# 80    Buxton   4/03/2017       3.3  ...    0     211.0         198.0
# 85  Marshall   7/05/2016       3.3  ...    1     153.0         180.0
# 88      Greg  10/09/2016       3.3  ...    1     199.0         107.0
# ...

# %%
melb_data[melb_data['Rooms'] == 3].shape[0]
# Out:
# 5881

# %%
melb_data[((melb_data['Rooms'] == 3) | (melb_data['BuildingArea'] > 100)) & (melb_data['Price'] < 300000)].shape[0]
# Out:
# 68

# %%
melb_data[melb_data['Type'] == 't']['Rooms'].max()
# Out:
# np.int64(5)

# %%
mean_price = melb_data['Price'].mean()
melb_data[melb_data['Price'] > mean_price]['BuildingArea'].median()
# Out:
# np.float64(126.0)

# %%
melb_data[melb_data['Bathroom'] == 0]['index'].count()
# Out:
# np.int64(34)

# %%
melb_data[(melb_data['Price'] > 3000000) & (melb_data['SellerG'] == 'Nelson')]['index'].count()
# Out:
# np.int64(5)

# %%
print(round(melb_data[(melb_data['Price'] < 1000000) & ((melb_data['Rooms'] > 5) | (melb_data['YearBuilt'] < 2015))]['Price'].mean(), 0))
ex8_4 = melb_data.loc[:,['Price', 'Rooms', 'YearBuilt']][(melb_data['Price'] < 1000000) & ((melb_data['Rooms'] > 5) | (melb_data['YearBuilt'] < 2015))]
display(ex8_4)
mask_2 = ex8_4['YearBuilt'] > 2015
display(ex8_4[mask_2].head())
mask_3 = melb_data['YearBuilt'] > 2015
display(melb_data[mask_3].head())
# Out:
# 673888.0
#           Price  Rooms  YearBuilt
# 3      850000.0      3       1970
# 5      941000.0      2       1970
# 8      300000.0      1       1970
# 10     700000.0      2       1970
# 12     750000.0      2       2009
# ...         ...    ...        ...
# 13568  951000.0      4       1981
# 13570  970000.0      3       1970
# 13572  650000.0      2       2006
# 13573  635000.0      4       1980
# 13574  582000.0      3       1970
#
# [7678 rows x 3 columns]
# Empty DataFrame
# Columns: [Price, Rooms, YearBuilt]
# Index: []
#       index            Suburb            Address  Rooms Type      Price  \
# 38       38      Airport West      154 Halsey Rd      3    t   840000.0
# 411     411           Ashwood  1/53 Winbirra Pde      4    h  1200000.0
# 441     441  Avondale Heights     157 Canning St      3    t   851000.0
# 535     535            Balwyn     316 Belmore Rd      4    h  1750000.0
# 1209   1209     Brighton East   25 Camperdown St      5    h  2550000.0
#
# ...

# %%
melb_data[(melb_data['Type'] == 'h') & (melb_data['Price'] < 3000000)]['Regionname'].value_counts()
# Out:
# Regionname
# Northern Metropolitan         2737
# Southern Metropolitan         2520
# Western Metropolitan          2286
# Eastern Metropolitan          1167
# South-Eastern Metropolitan     387
# Eastern Victoria                50
# Northern Victoria               41
# Western Victoria                32
# Name: count, dtype: int64
